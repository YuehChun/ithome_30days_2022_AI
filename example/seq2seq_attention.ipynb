# %%
# !pip install -U torch==1.8.0+cu111
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 torchtext==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Reload environment
exit()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.8.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.8.0%2Bcu111-cp37-cp37m-linux_x86_64.whl (1982.2 MB)
#      |█████████████▌                  | 834.1 MB 1.4 MB/s eta 0:13:56tcmalloc: large alloc 1147494400 bytes == 0x3abcc000 @  0x7f8f0609f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |█████████████████               | 1055.7 MB 1.2 MB/s eta 0:12:27tcmalloc: large alloc 1434370048 bytes == 0x7f222000 @  0x7f8f0609f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |█████████████████████▋          | 1336.2 MB 1.2 MB/s eta 0:08:57tcmalloc: large alloc 1792966656 bytes == 0x4054000 @  0x7f8f0609f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |███████████████████████████▎    | 1691.1 MB 1.2 MB/s eta 0:04:10tcmalloc: large alloc 2241208320 bytes == 0x6ee3c000 @  0x7f8f0609f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |████████████████████████████████| 1982.2 MB 1.2 MB/s eta 0:00:01tcmalloc: large alloc 1982251008 bytes == 0xf479e000 @  0x7f8f0609e1e7 0x4b2590 0x4b261c 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6
# tcmalloc: large alloc 2477817856 bytes == 0x1deebc000 @  0x7f8f0609f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x4bad99 0x4d3249
#      |████████████████████████████████| 1982.2 MB 5.0 kB/s
# Collecting torchvision==0.9.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torchvision-0.9.0%2Bcu111-cp37-cp37m-linux_x86_64.whl (17.6 MB)
#      |████████████████████████████████| 17.6 MB 19 kB/s
# Collecting torchaudio==0.8.0
#   Downloading torchaudio-0.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 8.7 MB/s
# Collecting torchtext==0.9.0
#   Downloading torchtext-0.9.0-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 27.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0+cu111) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0+cu111) (1.21.6)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.9.0+cu111) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.9.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.9.0) (4.64.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9.0) (2022.9.24)
# Installing collected packages: torch, torchvision, torchtext, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.13.1
#     Uninstalling torchtext-0.13.1:
#       Successfully uninstalled torchtext-0.13.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
#     Uninstalling torchaudio-0.12.1+cu113:
#       Successfully uninstalled torchaudio-0.12.1+cu113
# Successfully installed torch-1.8.0+cu111 torchaudio-0.8.0 torchtext-0.9.0 torchvision-0.9.0+cu111

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.legacy.data import Field, TabularDataset, BucketIterator
import numpy as np
import spacy
import random
from torchtext.data.metrics import bleu_score
import sys
import os
import re

# %%
import torch, torchtext
print(torch.__version__)
print(torchtext.__version__)
# Out:
# 1.8.0+cu111
# 0.9.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python -m spacy download zh_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting zh-core-web-sm==3.4.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.4.0/zh_core_web_sm-3.4.0-py3-none-any.whl (48.4 MB)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from zh-core-web-sm==3.4.0) (3.4.1)
# Requirement already satisfied: spacy-pkuseg<0.1.0,>=0.0.27 in /usr/local/lib/python3.7/dist-packages (from zh-core-web-sm==3.4.0) (0.0.32)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (4.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2.4.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (8.1.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (57.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (1.0.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (3.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (1.21.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (0.6.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (1.9.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->zh-core-web-sm==3.4.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('zh_core_web_sm')

# %% [markdown]
# # 需要處理一下json 裡面的資料

# %%
spacy_zh = spacy.load("zh_core_web_sm")
spacy_eng = spacy.load("en_core_web_sm")

def tokenize_eng(text):
    text = re.sub(r"([.!?])", r" \1", text)
    return [tok.text for tok in spacy_eng.tokenizer(text)]


def tokenize_zh(text):
    regex = re.compile(r'[^\u4e00-\u9fa5A-Za-z0-9]')
    text = regex.sub(' ', text)

    return [tok.text for tok in spacy_zh.tokenizer(text)]


english = Field(sequential=True, use_vocab=True, tokenize=tokenize_eng, lower=True)
chinese = Field(sequential=True, use_vocab=True, tokenize=tokenize_zh, lower=True)

fields = {"English": ("eng", english), "Chinese": ("zh", chinese)}

train_data, val_data, test_data = TabularDataset.splits(
    path="/content/drive/MyDrive/Colab Notebooks/ithome/torchtext_anki/", 
    train="anki_train.json", 
    validation="anki_val.json", 
    test="anki_test.json", 
    format="json", 
    fields=fields
)


english.build_vocab(train_data,min_freq=1)
chinese.build_vocab(train_data,min_freq=1)

print ("中文語料的字元表長度: " , len(chinese.vocab) , ", 英文的字元表長度: " ,len(english.vocab))
print ("Sample English:", test_data[0].eng , "=> Chinese:", test_data[0].zh)
# Out:
# 中文語料的字元表長度:  13535 , 英文的字元表長度:  6607
# Sample English: ['i', "'ve", 'been', 'very', 'busy', 'lately', '.'] => Chinese: ['我', '最近', '忙', '得', '很']

# %%
def translate_sentence(model, sentence, chinese, english, device, max_length=50):
    
    # 先載入 tokensizer
    spacy_zh = spacy.load("zh_core_web_sm")

    # Create tokens using spacy and everything in lower case (which is what our vocab is)

    model.eval()
    
    if type(sentence) == str:
        tokens = [token.text.lower() for token in spacy_zh(sentence)]
    else:
        tokens = [token.lower() for token in sentence]


    # 加入開始符號跟結束符號，代表一個句子
    tokens.insert(0, chinese.init_token)
    tokens.append(chinese.eos_token)
    # 上面等於下面
    # tokens = [src_field.init_token] + tokens + [src_field.eos_token]

    # 然後把文字轉自 vactor
    text_to_indices = [chinese.vocab.stoi[token] for token in tokens]

    # 再把 vactor list 轉換成 Tensor
    sentence_tensor = torch.LongTensor(text_to_indices).unsqueeze(1).to(device)

    # 取消梯度修正
    with torch.no_grad():
        outputs_encoder, hiddens, cells = model.encoder(sentence_tensor)

    # 先宣告 outputs ，然後裡面放一個開符號
    outputs = [english.vocab.stoi["<sos>"]]


    for _ in range(max_length):
        previous_word = torch.LongTensor([outputs[-1]]).to(device)

        # seq2seq 的decoder 會把上一個 hidden_state 跟 cell 當作input 這是觀念
        # 然後output機率最大的
        with torch.no_grad():
            output, hiddens, cells = model.decoder(
                previous_word, outputs_encoder, hiddens, cells
            )
            best_guess = output.argmax(1).item()

        # 機率最大的數值再把它放進output
        outputs.append(best_guess)

        # 如果是結束字元 eos 的話就中斷不然會一直預測下去
        if output.argmax(1).item() == english.vocab.stoi["<eos>"]:
            break

    # 再把 vactor 轉成文字， itos = integer to string
    translated_sentence = [english.vocab.itos[idx] for idx in outputs]

    # remove start token
    return translated_sentence[1:]



def bleu(data, model, chinese, english, device):
    targets = []
    outputs = []

    for example in data:
        src = vars(example)["zh"]
        trg = vars(example)["eng"]

        prediction = translate_sentence(model, src, chinese, english, device)
        prediction = prediction[:-1]  # remove <eos> token

        targets.append([trg])
        outputs.append(prediction)

    return bleu_score(outputs, targets)


def save_checkpoint(state, filename="/content/drive/MyDrive/Colab Notebooks/ithome/checkpoints/seq2seq_attention.pth.tar"):
    print("=> Saving checkpoint")
    torch.save(state, filename)


def load_checkpoint(checkpoint, model, optimizer):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, num_layers, p):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, bidirectional=True)

        self.fc_hidden = nn.Linear(hidden_size * 2, hidden_size)
        self.fc_cell = nn.Linear(hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        # x: (seq_length, N) where N is batch size

        embedding = self.dropout(self.embedding(x))
        # embedding shape: (seq_length, N, embedding_size)

        encoder_states, (hidden, cell) = self.rnn(embedding)
        # outputs shape: (seq_length, N, hidden_size)

        # Use forward, backward cells and hidden through a linear layer
        # so that it can be input to the decoder which is not bidirectional
        # Also using index slicing ([idx:idx+1]) to keep the dimension

        # 因為使用雙向的話會有 0 跟 1 代表正向跟反向 ，所以這邊會需要cat起來
        hidden = self.fc_hidden(torch.cat((hidden[0:1], hidden[1:2]), dim=2))
        cell = self.fc_cell(torch.cat((cell[0:1], cell[1:2]), dim=2))

        # encoder_states => 是最後的狀態, h1 h2 h3 放在hidden 裡面
        return encoder_states, hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(
        self, input_size, embedding_size, hidden_size, output_size, num_layers, p
    ):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(hidden_size * 2 + embedding_size, hidden_size, num_layers)

        self.energy = nn.Linear(hidden_size * 3, 1)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(p)
        self.softmax = nn.Softmax(dim=0)
        self.relu = nn.ReLU()

    def forward(self, x, encoder_states, hidden, cell):
        x = x.unsqueeze(0)
        # x: (1, N) where N is the batch size

        embedding = self.dropout(self.embedding(x))
        # embedding shape: (1, N, embedding_size

        # hidden 應該要視為把encoder 的結果做 fc(h1 ,h2 h3)

        sequence_length = encoder_states.shape[0]
        h_reshaped = hidden.repeat(sequence_length, 1, 1)
        # h_reshaped: (seq_length, N, hidden_size*2)

        #  encoder_states 應該為fc後的結果 = fc( final hidden state 3 or decoder_h1 h2 h3)
        energy = self.relu(self.energy(torch.cat((h_reshaped, encoder_states), dim=2)))
        # energy: (seq_length, N, 1)

        # energy 應該為 s1 , s2 , s3，

        attention = self.softmax(energy)
        # attention: (seq_length, N, 1)
        # attention score

        # attention: (seq_length, N, 1), snk
        # encoder_states: (seq_length, N, hidden_size*2), snl
        # we want context_vector: (1, N, hidden_size*2), i.e knl

        # context_vector 計算方法利用 einsum 來處理，如果詳細拆解如下放
        context_vector = torch.einsum("snk,snl->knl", attention, encoder_states)
        # context_vector = attention weight * encoder_states

        #### 原始寫法
        # attention (seq_lens, N, 1)
        # attention = attention.permute(1,2,0) # => attention (N, 1, seq_lens)
        # encoder_state (seq_length, N, hidden_size*2)
        # encoder_state = encoder_state.permute(1,0,2) # => (N, seq_lens, hidden_size*2)
        # context_vector = torch.bmm(attention, encoder_state).permute(1,0,2) # 相乘
        # torch.bmm(attention, encoder_state) => (N, 1, hidden_size*2) => permute 之後 (1, N, hidden_size*2)

        rnn_input = torch.cat((context_vector, embedding), dim=2)
        # rnn_input: (1, N, hidden_size*2 + embedding_size)
        outputs, (hidden, cell) = self.rnn(rnn_input, (hidden, cell))
        # outputs shape: (1, N, hidden_size)

        predictions = self.fc(outputs).squeeze(0)
        # predictions: (N, hidden_size)

        return predictions, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, source, target, teacher_force_ratio=0.5):
        # print(source.shape)
        batch_size = source.shape[1]
        target_len = target.shape[0]
        target_vocab_size = len(english.vocab)

        outputs = torch.zeros(target_len, batch_size, target_vocab_size).to(device)
        # 這邊多一個output = encoder_states
        encoder_states, hidden, cell = self.encoder(source)

        # First input will be <SOS> token
        x = target[0]

        for t in range(1, target_len):
            # At every time step use encoder_states and update hidden, cell
            output, hidden, cell = self.decoder(x, encoder_states, hidden, cell)
            # hidden 跟 cell 都是上個計算的結果導入這邊繼續計算

            # Store prediction for current time step
            outputs[t] = output

            # Get the best word the Decoder predicted (index in the vocabulary)
            best_guess = output.argmax(1)

            # With probability of teacher_force_ratio we take the actual next word
            # otherwise we take the word that the Decoder predicted it to be.
            # Teacher Forcing is used so that the model gets used to seeing
            # similar inputs at training and testing time, if teacher forcing is 1
            # then inputs at test time might be completely different than what the
            # network is used to. This was a long comment.
            x = target[t] if random.random() < teacher_force_ratio else best_guess
            # teacher force ratio 是用來協助訓練收斂的部分

        return outputs

# %%
checkPointPath = "/content/drive/MyDrive/Colab Notebooks/ithome/checkpoints/seq2seq_attention.pth.tar"


num_epochs = 1000
learning_rate = 0.001
batch_size = 32

# Model hyperparameters
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

input_size_encoder = len(chinese.vocab)
input_size_decoder = len(english.vocab)
output_size = len(english.vocab)
encoder_embedding_size = 200
decoder_embedding_size = 200
hidden_size = 512 # Needs to be the same for both RNN's
num_layers = 1
enc_dropout = 0.0
dec_dropout = 0.0

# %%
# Tensorboard to get nice loss plot
# writer = SummaryWriter(f"/content/drive/MyDrive/Colab Notebooks/ithome/runs/loss_plot")
step = 0

train_iterator, test_iterator = BucketIterator.splits(
    (train_data, test_data),
    batch_size=batch_size,
    sort_within_batch=True,
    sort_key = lambda x: len(x.zh),
    device=device,
)

# %%
encoder_net = Encoder(input_size_encoder, encoder_embedding_size, hidden_size, num_layers, enc_dropout).to(device)

decoder_net = Decoder(
    input_size_decoder,
    decoder_embedding_size,
    hidden_size,
    output_size,
    num_layers,
    dec_dropout,
).to(device)

# %%
model = Seq2Seq(encoder_net, decoder_net).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

pad_idx = english.vocab.stoi["<pad>"]
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

if os.path.isfile(checkPointPath):
    load_checkpoint(torch.load(checkPointPath ), model, optimizer)


score = bleu(test_data[1:100], model, chinese, english, device)
print(f"The last checkpoint of BLEU score :{score*100:.2f}")
# Out:
# => Loading checkpoint
# The last checkpoint of BLEU score :1.11

# %%
sentence = "你想不想要来我家看猫或一起看Netflix?"

for epoch in range(num_epochs):
    print(f"[Epoch {epoch} / {num_epochs}]")

    checkpoint = {"state_dict": model.state_dict(), "optimizer": optimizer.state_dict()}
    save_checkpoint(checkpoint)

    model.eval()

    translated_sentence = translate_sentence(
        model, sentence, chinese, english, device, max_length=50
    )

    print(f"Translated example sentence: \n {translated_sentence}")

    model.train()

    for batch_idx, batch in enumerate(train_iterator):
        # Get input and targets and get to cuda
        inp_data = batch.zh.to(device)
        target = batch.eng.to(device)

        # Forward prop
        output = model(inp_data, target)
        # Output is of shape (trg_len, batch_size, output_dim) but Cross Entropy Loss
        # doesn't take input in that form. For example if we have MNIST we want to have
        # output to be: (N, 10) and targets just (N). Here we can view it in a similar
        # way that we have output_words * batch_size that we want to send in into
        # our cost function, so we need to do some reshapin. While we're at it
        # Let's also remove the start token while we're at it
        output = output[1:].reshape(-1, output.shape[2])
        target = target[1:].reshape(-1)

        optimizer.zero_grad()
        loss = criterion(output, target)

        # Back prop
        loss.backward()

        # Clip to avoid exploding gradient issues, makes sure grads are
        # within a healthy range
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

        # Gradient descent step
        optimizer.step()

        # Plot to tensorboard
        # writer.add_scalar("Training loss", loss, global_step=step)
        step += 1
# Out:
# [Epoch 0 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'see', 'the', 'you', 'like', 'a', 'look', 'after', 'i', 'want', 'the', 'train', '.', '.', '.', "n't", 'see', 'your', 'computer', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 1 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'even', 'to', 'to', 'show', 'you', 'something', 'to', 'see', 'the', 'cake', 'and', 'i', 'do', "n't", 'read', 'it', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 2 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'the', 'cake', 'if', 'you', 'want', 'to', 'see', 'the', 'cake', '.', '.', 'eat', 'out', 'of', 'your', 'computer', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 3 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'you', 'want', 'to', 'have', 'a', 'look', 'at', 'the', '.', 'just', 'too', 'look', 'at', 'eleven', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 4 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'the', 'and', 'you', 'have', 'to', 'see', 'your', 'cake', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 5 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'even', 'want', 'to', 'take', 'the', 'look', 'at', 'night', '.', 'you', "'ll", 'have', 'a', 'look', 'at', 'the', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 6 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'even', 'to', 'to', 'look', 'after', 'you', 'and', 'relax', 'in', 'a', 'while', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 7 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'the', 'and', 'a', 'drop', 'with', 'my', 'cake', 'and', 'you', 'like', 'the', 'rest', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 8 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'the', 'early', ',', 'you', "'d", 'like', 'to', 'see', 'the', 'bag', '.', '"', 'relax', '.', '"', '"', 'please', '.', '"', '"', 'please', '.', '"', 'see', 'you', '.', '"', '"', 'please', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.']
# [Epoch 9 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'even', 'to', 'watch', 'the', 'cake', ',', 'you', 'must', 'have', 'a', 'look', 'at', 'your', 'gift', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '"', 'a', 'cold', '.', '"', '"', 'please', '.', '"', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.']
# [Epoch 10 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'you', 'to', 'see', 'the', 'best', ',', 'you', 'have', 'a', 'cup', 'of', 'them', '.', 'relax', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'please', '.', '.', '"', 'please', '.']
# [Epoch 11 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'you', 'like', 'the', 'early', ',', 'and', 'some', 'medicine', 'will', 'take', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 12 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['and', 'do', "n't", 'want', 'to', 'miss', 'you', 'to', 'see', 'the', 'mouth', 'of', 'your', 'family', '.', 'some', '.', '.', '"', '"', 'a', 'few', 'days', '.', '"', '"', 'please', '.', '"', '"', 'please', '.', '"', '.', '.', '"', '"', 'please', '.', '"', '.', '.', '"', '"', 'please', '.', '"', '.', '.', '"']
# [Epoch 13 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'the', 'cake', ',', 'and', 'you', 'like', 'to', 'see', 'the', 'movies', '.', 'break', '.', 'please', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '.', '"', '.', '"', '.', '"', '.', '"', 'please', '.', '"']
# [Epoch 14 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'the', 'magazine', ',', 'you', 'want', 'to', 'visit', 'your', 'dog', '.', '.', '.', '.', '.', 'break', 'your', 'dog', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 15 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'even', 'want', 'to', 'see', 'the', 'mouth', 'and', 'you', 'have', 'some', 'other', 'on', 'your', 'family', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 16 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  [',', 'do', "n't", 'want', 'to', 'see', 'you', 'and', 'me', 'to', 'see', 'your', 'cake', '.', 'do', "n't", 'have', 'a', 'look', 'at', 'eleven', '.', '.', '.', 'please', '.', '.', '.', '.', 'please', '.', '.', '.', 'please', '.', '.', '.', 'please', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 17 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'watch', 'the', 'and', 'light', 'with', 'you', '.', 'and', 'smoke', '.', '.', 'your', 'family', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 18 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'watch', 'any', 'further', '.', 'you', 'do', "n't", 'want', 'to', 'visit', 'them', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '"', 'a', 'hand', '.', '.', '"', '.', '"', '"', '.', '.', '"', '"', 'a', '.', '"', '"', '.', '.', '"', '"', 'see', 'a', 'look', '.']
# [Epoch 19 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'go', 'to', 'see', 'you', 'after', 'the', 'movies', 'on', 'your', 'family', '.', 'and', 'to', 'tv', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'watch', 'tv', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 20 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'fail', 'you', ',', 'used', 'to', 'see', 'a', 'movie', '.', 'breakfast', '.', '.', '.', '"', '"', 'i', 'have', 'a', 'child', '.', '.', '"', '"', 'a', 'movie', '?', '?', '"', '"', '.', '.', '"', '"', 'take', 'a', 'look', 'at', 'night', '?', '.', '"', '.', '.', '"', '"', 'a']
# [Epoch 21 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'eat', 'out', 'of', 'your', 'mouth', 'and', 'you', 'feel', 'like', 'taking', 'a', 'cup', 'of', 'coffee', '?', '.', '.', '.', '.', '.', '.', '.', '.', '.', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 22 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'miss', 'the', 'old', 'and', 'your', 'family', '.', '.', '.', "n't", 'you', 'like', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '"', 'a', 'look', '.', '"', '"', 'a', 'look', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.']
# [Epoch 23 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'go', 'to', 'you', 'and', 'see', 'our', 'cake', 'and', 'you', "'ll", 'have', 'a', 'look', 'at', 'your', 'family', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 24 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['!', 'do', "n't", 'want', 'to', 'see', 'you', 'while', 'we', 'are', "n't", 'taking', 'a', 'look', 'at', 'eleven', '.', '.', '"', '"', 'night', '?', '.', '"', '"', 'a', 'watch', 'tv', '.', '"', '"', '.', '.', '"', 'night', '?', '.', '"', 'please', '.', '"', '"', '.', '.', '"', '.', '.', '"', '.', '.']
# [Epoch 25 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['does', "n't", 'want', 'to', 'to', 'you', 'want', 'to', 'see', 'a', 'look', 'at', 'your', 'family', '.', 'i', 'have', 'a', 'good', 'visit', 'you', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 26 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'watch', 'us', 'you', 'like', 'to', 'see', 'a', 'look', 'at', 'your', 'family', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 27 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['it', "'s", 'not', 'to', 'want', 'to', 'take', 'you', 'to', 'wait', 'for', 'you', '.', '.', '.', '.', 'breakfast', '.', '.', '.', '.', 'bit', 'hand', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 28 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'have', 'a', 'drop', ',', 'and', 'your', 'time', '.', 'i', 'prefer', 'free', 'to', 'visit', 'you', '.', '.', '.', '.', 'night', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 29 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'watch', 'out', 'of', 'the', 'light', 'on', ',', 'you', 'and', 'your', 'family', '.', '.', 'breakfast', '.', '.', '.', '.', '.', 'night', '.', '"', 'a', 'movie', '.', '.', '"', 'a', 'tv', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 30 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'show', 'you', 'want', 'the', 'taking', 'a', 'drink', ',', 'and', 'see', '.', 'you', 'have', "n't", 'walk', 'to', 'see', 'a', 'movie', '.', '.', '"', '.', 'please', '.', '.', '"', 'night', '.', '"', '.', '.', '"', '.', '.', '"', '.', '"', 'a', 'movie', '.', '.', '"', '.', '.', '.']
# [Epoch 31 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'like', 'to', 'visit', ',', 'and', 'your', 'family', '.', 'do', "n't", 'look', 'at', 'some', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 32 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['does', "n't", 'want', 'to', 'watch', 'this', 'kind', 'of', 'you', 'and', 'i', 'have', 'a', 'good', 'appetite', 'for', 'you', 'to', 'the', 'train', '.', 'please', '.', '.', '.', '.', '"', '.', 'please', '.', '"', '.', '.', '"', 'a', '.m', '.', 'you', '.', '.', '"', '.', '.', '"', 'a', '.m', '.', 'please', '.', '.']
# [Epoch 33 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'see', 'this', ',', 'and', 'your', 'complaining', 'to', 'visit', 'you', '.', '.', 'break', 'the', 'movies', 'on', 'a', 'movie', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 34 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'watch', 'any', 'more', 'if', 'it', "'s", 'day', 'or', 'you', 'to', 'visit', 'a', '.m', '.', '.', '.', '.', '.', '.', 'please', '.', '.', '?', 'night', '.', '"', '.', 'please', '.', '.', '"', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 35 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'watch', 'if', 'you', 'feel', 'like', '.', '.', 'your', 'family', '.', '.', '.', '.', '.', '"', '.', 'i', "'ve", 'up', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"']
# [Epoch 36 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['last', ',', 'i', 'do', "n't", 'want', 'to', 'see', 'you', 'a', 'child', 'does', "n't", 'join', 'your', 'room', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 37 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['this', 'matter', 'what', 'do', 'you', 'want', 'to', 'watch', 'a', 'day', 'or', 'i', 'have', 'a', 'look', 'at', 'this', 'time', '.', 'relax', '.', 'a', 'bridge', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 38 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'see', 'the', ',', 'you', 'do', "n't", 'have', 'to', 'see', 'the', 'cake', 'and', 'see', 'a', 'look', 'at', 'night', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 39 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'see', 'the', 'children', 'to', 'a', 'on', 'the', 'family', '.', '.', '.', 'dark', '.', 'a', 'bridge', '.', '.', '.', 'a', 'bridge', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 40 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'watch', 'the', 'meat', ',', 'and', 'your', 'family', 'did', "n't", 'have', 'a', 'child', '.', 'i', 'can', 'open', '.', 'child', '.', 'a', 'park', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 41 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'watch', 'out', ',', 'you', 'do', "n't", 'have', 'to', 'see', 'the', 'tv', ',', 'i', 'do', "n't", 'see', 'a', 'look', '.', '.', '.', '.', '.', '.', 'bit', '.', 'a', 'bit', '.', '.', 'bit', '.', '.', 'dark', '.', 'a', 'bit', '.', '.', 'bit', '.', '.', '.', '.', '.', 'please']
# [Epoch 42 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'watch', 'any', 'a', 'light', 'on', 'my', 'place', '.', 'relax', ',', 'i', 'have', 'a', 'while', 'you', 'have', 'a', 'movie', '?', '?', '.', '.', 'a', 'list', '.', '.', '.', '.', 'tv', '?', '.', '.', '"', '"', '.', 'a', 'bus', '.', '"', '.', 'a', 'bit', '.', '"', '"']
# [Epoch 43 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'watch', 'tv', ',', 'i', 'do', "n't", 'have', 'a', 'look', 'at', 'your', 'family', '.', '"', 'a', 'bit', 'album', '?', '.', '"', 'a', 'haircut', '?', 'hand', '?', '.', '"', '.', '.', '"', '.', 'relax', '.', '"', '.', '.', '"', 'read', '.', '"', '.', '.', '"', 'read', '.']
# [Epoch 44 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['object', 'to', 'do', "n't", 'want', 'to', 'watch', 'tv', 'if', 'you', 'do', 'it', ',', 'you', "'ll", 'have', 'to', 'the', 'time', '.', 'night', '.', 'a', 'bit', '.', '.', 'dark', '.', 'dark', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'bit']
# [Epoch 45 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'if', 'you', 'must', 'not', 'rest', 'the', 'the', 'time', 'time', '.', 'your', 'family', '.', '.', 'dark', '.', 'dark', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 46 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['object', 'to', 'do', "n't", 'want', 'to', 'see', 'you', 'a', ',', 'or', 'you', 'have', 'to', 'take', 'a', 'rest', '.', '.', '.', '.', 'your', 'class', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 47 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'like', 'to', 'go', 'and', 'see', 'the', 'best', 'day', '.', 'and', 'i', 'like', 'your', 'place', '.', 'coffee', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '.', '"', '"', '.', 'take', 'a', '.', '"', '.', '"', 'a', '.', '"', 'night', '.', '"', 'a', 'few', 'days']
# [Epoch 48 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'smoke', 'after', 'my', 'family', '.', 'coffee', '.', 'not', 'have', 'a', 'cold', '.', '.', '"', '"', 'i', 'have', "n't", 'sleep', '.', '.', '"', '"', '.', 'you', "'ve", '.', '"', '"', '.', 'it', '.', '"', 'a', 'cold', '.', '"', '.', '.', '"', 'a', '.', '"', 'a', 'few']
# [Epoch 49 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'move', 'this', 'you', 'want', 'to', 'buy', 'this', 'a', 'time', 'i', 'just', 'have', 'to', 'see', 'a', 'bike', '.', '"', 'i', 'have', '.', '"', 'read', '.', '"', '.', '.', '"', '"', '.', 'it', '.', '"', '.', '"', '.', '.', '"', 'a', 'few', 'days', '.', '"', '"', 'i', 'have']
# [Epoch 50 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['can', 'not', 'like', 'you', 'to', 'send', 'this', 'movie', 'by', 'some', '.', '.', 'i', 'have', 'no', '.', '.', '.', '.', '"', 'a', 'you', '.', '"', 'so', '.', '.', '"', '"', '.', '.', '"', '.', '"', '.', '"', '.', '"', '.', '"', '.', '"', '"', '.', '.', '"', '.', '"', '.', '"']
# [Epoch 51 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'watch', 'this', 'evening', '.', 'you', "'d", 'like', 'to', 'stay', 'a', 'car', ',', 'i', 'have', "n't", 'have', 'a', 'movie', '.', '.', '.', '.', '.', '.', '.', '"', '"', '.', '"', '"', 'read', '.', '"', '"', '.', '"', 'read', '.', '"', '"', 'i', 'have', 'a', 'house', '.', '.', '"']
# [Epoch 52 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'see', 'your', 'teacher', 'and', 'i', 'want', 'to', 'see', 'a', 'movie', '.', '.', '.', 'does', "n't", 'have', 'a', 'house', '.', '.', '.', '.', '.', '.', '"', '"', 'i', 'have', 'a', '.', '.', '.', '.', '"', '"', 'see', 'me', '.', '"', '"', 'i', 'have', 'a', '.', '.', '"']
# [Epoch 53 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'stay', 'very', 'early', 'if', 'you', 'wanted', 'to', 'see', 'my', 'place', '.', 'relax', '.', '.', '"', '"', 'i', 'have', 'a', 'few', 'japanese', '.', '.', '"', '"', 'it', '.', '.', '"', '"', '.', '"', '"', 'i', 'have', 'a', '.', '.', '"', '"', '.', 'you', '.', '"', '"', 'i']
# [Epoch 54 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'stay', 'this', ',', 'i', 'do', "n't", 'have', 'to', 'see', 'a', 'movie', 'store', 'not', '.', 'a', 'night', '.', '.', '.', '.', '.', '.', '.', '.', '"', '"', 'i', 'have', "n't", '.', '.', '.', '"', '"', '.', '.', '"', '"', '.', '"', '"', 'i', '.', '.', '"', '"']
# [Epoch 55 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'stay', 'this', 'car', ',', 'i', 'do', "n't", 'have', 'to', 'see', 'a', 'movie', 'movie', 'a', 'movie', '.', 'flower', '.', 'relax', '.', '.', 'house', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 56 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'smoke', 'look', 'at', 'your', 'family', '.', 'do', "n't", 'want', 'to', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 57 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['to', 'do', "n't", 'want', 'to', 'watch', 'and', 'if', 'you', 'have', 'time', 'to', 'see', 'my', 'exams', '.', 'relax', '.', '.', 'conference', 'in', 'or', 'coffee', '?', '"', '"', 'night', '.', '"', '"', '.', '.', '"', 'night', '.', '.', '"', '.', '.', '"', '.', '.', '"', '"', '.', '.', '"', '.', '.', '"']
# [Epoch 58 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['to', 'i', 'prefer', 'you', 'to', 'stay', 'this', 'hotel', ',', 'and', 'have', 'a', 'time', 'games', 'is', "n't", 'the', 'time', '.', '"', '"', 'i', 'have', 'a', '.', '.', '.', '"', '"', '.', 'list', '.', '"', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '"', '"', 'read', '.', '"', '"']
# [Epoch 59 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['to', 'want', 'you', 'like', 'this', 'movie', 'with', 'you', 'have', 'time', 'to', 'the', 'floor', '.', '"', '"', 'i', 'have', 'a', 'cold', '.', '.', '"', '"', 'i', 'have', 'a', '.', '.', '.', '"', '.', '.', '"', '"', '.', '.', '"', '"', '.', '.', '"', '"', '.', '.', '"', '"', '.', '.', '"']
# [Epoch 60 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'you', 'want', 'a', 'drink', ',', 'and', 'have', "n't", 'i', 'prefer', 'moving', 'coffee', 'in', 'my', 'days', '.', 'i', 'ca', "n't", 'have', 'a', 'walk', '.', 'the', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 61 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'you', 'want', 'to', 'smoke', 'with', 'my', 'sister', '.', 'in', 'your', 'family', '.', 'you', 'do', "n't", 'have', 'a', 'bicycle', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '"', 'i', 'hot', '.', '.', '"', '"', 'i', 'have', 'few', 'days', '.', '.', '"', '"', '.', '"', '"', '.', '"']
# [Epoch 62 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'stay', 'with', 'my', 'movie', 'if', 'you', 'like', 'the', 'summer', '.', '"', '"', 'i', 'you', 'you', '.', '"', 'i', 'you', '.', '"', 'sit', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '"', 'read', '.', '"', '.', '.', '"', '.', '.', '"', '.']
# [Epoch 63 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['to', 'move', 'you', 'like', 'this', 'a', ',', 'and', 'you', 'have', "n't", 'miss', 'this', 'family', 'yet', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'room', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 64 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'move', 'out', 'and', 'see', 'you', 'something', 'in', 'the', 'family', 'affairs', '.', '.', '.', '.', "n't", 'you', 'have', 'a', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 65 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['want', 'want', 'some', 'of', 'this', 'company', 'will', "n't", 'you', '.', 'the', 'rest', 'of', 'the', '.', 'days', '.', 'will', 'not', '.', 'the', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 66 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['who', 'do', "n't", 'want', 'to', 'have', 'a', 'moving', 'with', 'you', 'on', 'the', 'meal', ',', 'or', 'on', 'the', 'bus', '.', '.', '.', '.', '"', '"', 'i', 'have', "n't", '.', 'a', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '"', '"', '.', '"', '"', '.', '"', '"', '.', '.', '"']
# [Epoch 67 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['together', 'will', 'find', 'some', 'flowers', 'for', 'you', '.', 'the', 'summer', 'i', 'do', "n't", 'want', 'to', '.', 'for', 'a', 'few', 'days', '.', '.', 'you', '.', '.', '.', '.', '.', '"', '"', '.', 'a', 'room', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.']
# [Epoch 68 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['and', 'see', 'you', 'for', 'christmas', 'for', 'a', 'few', 'even', 'for', 'for', 'next', 'time', '.', 'summer', 'i', 'have', 'a', 'good', 'while', '.', '"', 'i', 'am', '.', 'the', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 69 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['mother', 'will', 'not', 'like', 'to', 'move', 'this', 'movie', 'will', 'see', 'you', '.', '.', '.', 'not', 'too', '.', '.', 'you', 'have', "n't", 'see', '.', 'a', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '.', '.', '"', '.', '"', 'i', 'have', 'a', '.', '.']
# [Epoch 70 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'see', 'the', 'early', ',', 'you', 'have', "n't", 'miss', 'this', 'movie', '.', 'summer', '.', '.', 'too', '.', '"', 'i', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 71 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'stay', ',', 'and', 'you', 'have', "n't", 'want', 'to', 'visit', 'me', '.', '"', 'i', 'do', "n't", 'want', 'to', 'drink', '.', 'summer', '.', '.', '"', 'i', 'have', 'a', 'look', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 72 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'see', 'this', 'movie', 'for', 'a', 'few', 'things', '.', 'the', 'time', '.', 'does', "n't", 'you', 'get', 'some', 'cold', '.', 'fish', '.', '.', '"', 'i', 'do', "n't", 'have', '.', '.', '.', '.', '"', '.', '"', '.', 'few', '.', '.', '"', '.', '"', '.', 'few', '.', '.', '"', '.']
# [Epoch 73 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'have', 'a', 'walk', 'with', 'the', 'summer', ',', 'where', 'you', 'want', 'to', 'get', 'some', 'good', '.', 'summer', '.', 'you', '?', "n't", '.', '.', 'days', '?', '?', '?', '.', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '.', '"', '"', 'i', '.', '.', '.']
# [Epoch 74 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'do', "n't", 'you', 'like', 'to', 'take', 'a', 'gift', 'for', 'the', 'family', 'affairs', '.', '.', '.', 'hat', '.', '"', '"', 'i', 'do', "n't", 'look', '.', '.', '.', '"', '"', 'i', '.', '.', '"', '"', 'his', '.', '.', '"', '"', '.', '"', '"', '.', 'smoking', '.', '"', '"', '.', '"', '"']
# [Epoch 75 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'have', 'to', 'miss', 'this', 'old', 'and', 'a', 'my', 'mom', '.', 'the', 'hotel', 'so', 'i', 'think', '.', 'this', 'car', '.', '.', '.', '.', '.', '.', 'bit', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 76 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['thank', 'you', 'want', 'this', 'old', 'and', 'miss', 'the', 'train', '.', 'have', "n't", 'you', 'washed', 'the', 'year', '.', 'do', "n't", 'have', 'this', 'time', '.', 'me', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 77 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'prefer', 'walking', 'to', 'the', 'newspaper', 'before', 'you', 'have', 'to', 'get', 'to', 'a', 'walk', 'in', 'the', 'house', '.', '.', '.', '.', 'bit', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 78 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'want', 'to', 'show', 'you', 'something', 'from', 'the', 'some', '.', 'and', "n't", 'want', 'to', 'see', '.', 'a', 'walk', '.', 'the', 'summer', '.', '"', '"', 'i', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '.', 'few', '.', 'few', '.', 'few', '.', 'few', '.', 'few', '.', '.', '"', '.']
# [Epoch 79 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'see', 'this', 'movie', 'with', 'a', 'walk', 'on', 'your', 'homework', '.', '.', '.', '.', '.', 'summer', '.', 'few', 'days', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 80 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'want', 'like', 'to', 'see', ',', 'and', 'your', 'family', ',', 'you', 'prefer', 'in', 'the', 'time', '.', 'what', 'longer', 'you', 'up', '?', 'summer', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', 'i', 'try', '.', '"', '"', 'so', '.', '.', '"', '.', '"', '"']
# [Epoch 81 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['should', 'miss', 'the', 'and', 'miss', 'the', 'family', 'long', 'time', 'to', 'see', '.', 'where', 'does', "n't", 'you', 'look', 'on', 'the', 'summer', '.', 'you', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 82 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['can', 'asked', 'me', 'to', 'smoke', '.', 'watching', 'you', 'on', 'your', 'back', '.', '.', '.', '.', 'show', 'the', 'dog', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 83 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['is', "n't", 'going', 'to', 'see', 'you', 'and', 'a', 'drop', 'in', 'your', 'family', ',', 'but', 'i', 'do', "n't", 'want', 'to', 'visit', 'a', 'few', 'days', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 84 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'see', 'the', 'picture', ',', 'you', 'prefer', 'in', 'the', 'family', '.', "n't", 'want', 'to', 'visit', 'you', '.', '.', 'summer', '.', 'summer', '.', 'you', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 85 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'miss', 'the', 'train', 'to', 'stay', ',', 'and', 'have', 'to', 'get', 'in', 'the', 'office', 'on', 'your', 'brother', '.', '.', '.', '.', 'summer', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 86 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['once', 'too', ',', 'to', 'you', 'want', 'to', 'get', 'some', 'the', 'job', ',', 'i', "'ll", 'have', 'to', 'sit', 'with', 'the', 'summer', '.', '.', 'bit', '.', '.', 'bit', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 87 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['mother', 'asked', 'do', "n't", 'want', 'to', 'get', 'to', 'the', 'and', 'your', 'parents', '.', 'in', 'the', 'same', '.', '.', 'list', '.', '.', 'bit', '.', '.', 'you', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 88 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'see', 'the', 'same', ',', 'do', "n't", 'have', 'to', 'watch', 'this', 'movie', '.', '"', 'i', 'do', "n't", 'see', '.', '.', '.', 'you', '.', '.', '"', '.', '.', '"', 'i', 'have', 'a', 'sunburn', '.', '.', 'days', '.', '.', '.', '.', '.', '.', '"', '.', '.', '.', '.', '.']
# [Epoch 89 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'see', 'the', 'best', 'to', 'sit', 'on', 'my', '.', '.', 'you', 'want', '.', '.', '.', 'bit', 'longer', '.', '.', '.', '.', 'bit', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 90 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['really', 'do', "n't", 'want', 'to', 'to', 'your', 'back', 'out', 'this', 'plan', '.', '.', 'wanted', 'you', '.', '.', 'wanted', 'to', 'get', '.', 'the', 'library', '.', '.', 'turning', "n't", 'you', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 91 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['just', 'do', "n't", 'want', 'to', 'to', 'you', 'want', 'to', 'take', 'a', 'look', 'at', 'the', 'job', '.', 'visit', 'you', '.', '.', '.', 'your', 'class', '.', '.', 'list', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 92 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['really', 'do', "n't", 'want', 'to', 'spoil', 'your', 'rent', ',', 'and', 'me', '.', 'the', 'train', '.', '.', 'train', '.', 'longer', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 93 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'have', 'to', 'pick', 'you', 'want', 'to', 'get', 'married', 'to', 'train', '.', 'where', 'does', "n't", 'have', 'to', 'bed', '?', '?', '.', '.', '.', '.', 'relax', '?', 'few', 'days', '.', '.', 'house', '.', '.', 'bit', 'longer', '?', '.', '.', '.', 'house', '.', '.', 'bit', '?', '.', '.', '.', '.']
# [Epoch 94 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['really', 'want', 'to', 'see', 'you', 'and', 'see', 'your', 'bicycle', '.', '.', 'days', '.', 'where', 'does', "n't", 'visit', 'you', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', 'please', '.', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 95 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', 'you', 'want', 'to', 'go', 'out', 'and', 'take', 'my', 'friend', 'the', 'tv', ',', 'but', 'i', 'do', "n't", 'look', 'for', 'a', 'sunburn', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 96 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', 'you', 'want', 'to', 'see', 'the', 'train', 'this', 'movie', 'with', 'you', 'wanted', 'to', 'catch', 'a', 'list', '.', '.', '.', 'visit', 'me', '.', '.', 'house', '.', '.', '?', '?', 'visit', 'visit', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '.', '.', '.', '.']
# [Epoch 97 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['just', 'do', "n't", 'want', 'to', 'show', 'you', 'to', 'visit', 'me', 'to', 'visit', 'the', 'other', 'tea', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 98 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'move', 'this', ',', 'but', 'you', 'have', 'to', 'have', 'a', 'look', 'at', 'the', 'hotel', '.', '.', 'bit', 'too', '.', '.', '.', '.', 'bit', 'too', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'bit', '.', '.', 'bit', '.', '.', 'bit', '.', '.', 'bit', '.']
# [Epoch 99 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'want', 'to', 'see', 'and', 'see', 'your', 'family', 'did', "n't", 'want', 'to', 'get', 'some', '.', '.', '"', '"', 'i', 'hope', '.', '"', '"', 'a', 'sunburn', '.', '"', '"', 'i', 'have', '.', '"', '"', '.', '.', '"', '"', '.', '.', '"', '"', '.', '.', '"', '"', '.', '.', '"', '"', '.']
# [Epoch 100 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'want', 'to', 'see', 'the', 'job', ',', 'and', 'have', 'you', 'used', 'to', 'get', 'off', '.', 'and', 'do', "n't", 'want', 'your', 'train', '.', '.', '"', '"', 'no', '.', '"', '"', 'no', '.', '.', '"', '"', 'his', 'place', '.', '"', '.', '.', '"', '.', '.', '"', 'smoking', '.', '.', '"', '.', '.']
# [Epoch 101 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'still', 'want', 'to', 'move', 'this', 'and', 'your', 'you', 'have', 'change', 'your', 'time', 'to', 'visit', 'and', 'i', 'hope', 'you', 'have', "n't", 'work', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 102 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'see', 'the', 'same', ',', 'you', 'do', "n't", 'have', 'to', 'sit', 'your', 'family', '.', '.', 'you', 'cut', 'to', 'the', 'office', '.', '"', '"', 'if', 'you', 'you', '.', '.', '"', '"', 'your', 'these', 'days', '.', '"', '.', '"', 'sit', '.', '.', '.', '.', 'bit', 'too', '.', '"', 'sit', '.']
# [Epoch 103 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'still', 'love', 'to', 'go', 'and', 'you', 'like', 'your', 'best', '.', 'your', 'family', '.', '.', '.', '.', '.', "n't", 'you', '?', '.', 'house', '.', '.', '.', '.', '.', '?', '?', '?', '?', '.', '?', 'my', 'house', '?', '.', '?', "n't", '.', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 104 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'want', 'to', 'see', 'the', 'time', 'you', 'want', 'to', 'smoke', '?', 'i', 'do', "n't", 'want', 'to', 'show', 'up', '?', 'you', '.', '?', '.', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 105 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['does', "n't", 'want', 'to', 'see', 'the', 'you', 'you', 'want', 'to', 'smoke', ',', 'and', 'do', "n't", 'you', 'asleep', '?', 'on', 'your', 'name', '?', 'i', '?', 'on', '.', 'visit', 'you', '?', '.', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 106 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['just', 'wanted', 'to', 'see', 'the', 'you', 'like', 'to', 'smoke', '.', 'where', 'to', 'do', "n't", 'want', 'to', 'show', 'them', '?', 'you', 'office', 'on', 'the', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 107 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'see', 'me', 'to', 'sit', 'wherever', 'the', '.', '.', '.', 'are', "n't", 'you', 'cat', '.', '.', '.', 'bit', 'too', '.', '.', 'house', '.', '.', 'bit', '.', 'house', '.', '.', 'list', '.', '.', '.', '.', '.', '.', 'bit', '?', 'house', '.', 'me', '.', '.', 'list', '.', '.', 'bit', '.']
# [Epoch 108 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['just', 'do', "n't", 'want', 'to', 'go', 'to', 'the', 'you', 'feel', 'like', 'time', ',', 'i', 'have', 'to', 'remember', 'you', '?', '.', 'i', 'do', "n't", 'catch', 'your', '?', '?', 'you', '?', "n't", 'you', '?', 'on', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 109 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'see', 'you', 'and', 'your', 'family', ',', 'but', 'you', 'you', "n't", 'like', 'your', 'shoes', 'off', '.', 'hand', 'is', "n't", 'too', '.', '.', '"', 'sit', 'down', '.', '"', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.']
# [Epoch 110 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'miss', 'the', 'last', 'time', 'to', 'give', 'to', 'see', 'the', 'mouth', '.', '.', 'house', '.', 'relax', '.', 'hand', '?', '.', '"', '.', 'i', 'have', 'a', 'sunburn', '.', '.', '"', '.', '"', '"', 'i', 'remember', '.', '"', '"', '.', '"', '.', '"', '.', '"', '.', '"', '.', '"', '.', '.', '"']
# [Epoch 111 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'miss', 'the', 'job', 'to', 'see', 'you', 'and', 'do', "n't", 'want', 'to', 'show', 'you', '.', '.', '.', 'do', "n't", 'you', 'want', 'to', 'sit', 'on', 'the', '.', '.', '.', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.']
# [Epoch 112 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'see', 'the', 'same', ',', 'you', 'just', 'like', 'the', 'job', ',', 'and', 'you', 'have', "n't", 'this', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'bit', '.', '.', '.']
# [Epoch 113 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'see', 'the', 'same', ',', 'and', 'i', 'do', "n't", 'want', 'to', 'show', 'you', 'to', 'visit', 'me', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '?', 'you', '?', '?', '?', '?', '?', 'you', '?']
# [Epoch 114 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'see', 'you', 'and', 'your', 'family', 'i', 'do', "n't", 'want', 'to', 'see', 'you', '.', 'your', 'your', 'house', '.', 'dark', '.', 'do', "n't", 'want', 'to', 'get', 'off', '.', 'your', 'teeth', '.', '.', 'bit', '?', 'you', '.', '.', 'bit', '?', '"', '.', 'your', 'class', '.', '.', '"', '.', '.', '"']
# [Epoch 115 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'see', 'you', ',', 'you', 'do', "n't", 'want', 'to', 'to', 'your', 'family', '.', 'dark', '.', '.', 'just', 'do', "n't", 'you', '.', '.', '.', "'s", "n't", 'you', '?', 'on', 'monday', '.', '"', '.', 'catch', 'you', '?', '.', '"', '.', 'bit', 'too', '.', '"', '.', '.', '"', '.', '.', '"']
# [Epoch 116 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'do', "n't", 'want', 'to', 'to', 'look', 'at', 'your', 'family', 'first', '.', '.', '.', 'do', "n't", 'look', 'so', '.', '.', '.', '.', '.', '.', '.', '.', 'bit', '.', '.', '.', '.', '.', 'bit', '.', '.', '.', '.', '.', '"', '.', '"', '.', '"', 'your', '.', 'bit', '.', '.', '"', '.']
# [Epoch 117 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['could', 'you', 'want', 'to', 'go', 'and', 'see', 'you', 'something', '.', 'it', "'s", 'my', 'too', 'to', 'sit', 'on', 'the', '.', '.', '.', '.', '.', '.', '.', '.', 'please', '.', '.', '"', '.', '.', '"', '.', '.', 'bit', '?', '?', '?', 'please', '.', '"', '.', '.', '"', '.', '.', '.', '"', '.']
# [Epoch 118 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["n't", 'do', "n't", 'want', 'to', 'to', 'your', 'your', 'parents', 'asked', 'to', 'have', 'to', 'visit', 'me', 'at', 'the', '.', '.', "'s", 'too', 'good', '.', '.', 'bit', '.', '.', '"', 'such', 'an', 'umbrella', '.', '.', '"', '.', '.', '"', 'your', 'place', '.', '"', '.', 'your', '?', '.', '"', '.', '.', '"', 'a']
# [Epoch 119 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'miss', 'this', 'car', 'if', 'you', 'want', 'to', 'smoke', '.', 'your', 'family', '.', '.', 'where', 'do', "n't", 'want', 'to', 'bed', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 120 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['could', 'you', 'want', 'to', 'see', 'you', 'want', 'to', 'smoke', 'to', 'to', 'smoke', 'and', 'see', 'to', 'your', 'family', '.', '.', '.', 'do', "n't", 'you', 'eat', '.', '.', '.', '.', 'too', '.', '.', 'work', '.', '.', 'dark', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 121 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['love', "n't", 'want', 'to', 'show', 'you', 'you', ',', 'you', 'do', "n't", 'want', 'to', 'turn', 'in', 'the', 'train', '.', 'you', "'ll", 'miss', 'the', 'train', '.', 'no', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'list', '.', '.', 'dark', '.', '.', '.', 'dark', '.', '.']
# [Epoch 122 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'do', "n't", 'want', 'to', 'show', 'me', 'to', 'the', 'station', 'if', 'you', 'want', 'to', 'bed', '.', '.', '.', '.', '.', 'your', 'night', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 123 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["n't", 'you', 'want', 'to', 'see', 'if', 'you', 'take', 'part', 'in', 'the', 'family', '.', 'and', 'you', 'do', "n't", 'complaining', 'on', 'your', 'trip', '.', '.', '.', '.', '.', '"', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', 'list', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.']
# [Epoch 124 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'do', "n't", 'want', 'to', 'show', 'up', 'to', 'you', 'want', 'to', 'catch', 'a', 'job', 'and', 'see', '.', '.', 'your', 'your', 'umbrella', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 125 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["n't", 'miss', 'you', 'to', 'see', 'if', 'smoking', 'is', "n't", '.', 'where', 'it', "'s", 'all', 'depends', 'on', 'the', '.', '.', '"', 'smoking', '.', '.', '"', '.', '"', 'changed', '.', '.', '.', '.', '.', '"', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 126 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['ca', "n't", 'want', 'to', 'show', 'it', 'to', 'you', '.', 'not', 'want', 'to', 'lose', 'weight', '.', '.', '.', '.', '.', '.', '.', '.', 'cold', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 127 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['mother', 'really', 'want', 'to', 'watch', 'tv', ',', 'you', 'do', "n't", 'want', 'to', 'visit', 'the', 'floor', '.', 'burn', 'it', '.', 'you', '.', '.', '"', 'i', 'do', "n't", 'want', 'to', 'read', '.', '.', '.', '.', '"', '.', '.', '.', '"', '.', '.', '.', '.', '"', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 128 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["n't", 'want', 'to', 'watch', 'the', 'tv', ',', 'you', 'do', "n't", 'want', 'to', 'get', 'cold', '.', 'you', 'do', "n't", 'want', 'to', 'get', 'to', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 129 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', "n't", 'like', 'to', 'see', 'if', 'you', 'want', 'a', '.', 'if', 'you', 'want', 'to', 'smoke', '.', 'the', 'fish', '.', '"', '"', 'i', 'that', 'i', 'do', "n't", 'want', '.', '.', '"', '"', '.', 'bit', '.', '"', '"', '.', '.', '"', '.', '"', '.', '"', '.', '"', '.', '"', '.', '"', '.']
# [Epoch 130 / 1000]
# => Saving checkpoint
# Translated example sentence:
# ...
# [Epoch 158 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['just', 'do', "n't", 'want', 'to', 'go', 'to', 'see', 'you', 'wherever', 'you', 'sit', 'down', 'on', 'smoking', '.', '.', 'does', "n't", 'check', 'your', 'watch', '.', '.', '.', '.', '.', '.', '"', '.', '"', '"', 'i', 'hope', 'to', '.', '.', '"', '"', 'i', 'think', '.', '"', '.', '"', '"', 'i', 'smoke', '.', '"']
# [Epoch 159 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'better', 'take', 'an', 'move', 'to', 'see', 'you', 'and', 'you', 'have', 'to', 'see', 'your', 'father', '.', 'where', 'time', 'always', 'take', 'me', '.', 'where', 'the', 'mouth', '?', 'give', 'my', 'house', '.', '.', '.', '"', '.', '"', '"', '.', '"', '"', 'i', 'think', '.', '"', '.', '"', '.', '"', '"', 'i', 'doubled']
# [Epoch 160 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["'d", 'like', 'to', 'see', 'your', 'umbrella', 'wherever', 'you', 'like', 'to', 'catch', 'a', 'in', 'your', 'family', '.', 'few', 'days', '.', 'i', 'do', '.', 'train', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '"', '.', 'relax', '.', '"', '.', 'relax', '.', '"', '.', 'away', '.', '"', '.', 'away', '.']
# [Epoch 161 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'want', 'to', 'move', 'and', 'see', 'you', 'and', 'your', 'family', '.', 'you', 'will', 'miss', 'miss', 'some', 'minutes', '.', '.', 'brings', "n't", 'want', 'to', 'visit', '.', '.', '.', '"', 'i', 'hope', 'i', 'get', 'your', 'bed', '.', '.', '"', '.', '"', '.', '"', 'i', 'have', 'to', 'bed', '.', '.', '"', '.', '"']
# [Epoch 162 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'see', 'your', 'umbrella', ',', 'you', "'d", 'like', 'to', 'see', 'the', 'museum', '.', 'encouraged', 'your', 'summer', '.', '.', '.', '.', '.', '.', '.', '"', 'i', 'fell', '.', '.', '"', '.', '"', 'i', 'doubled', '.', '"', '.', '.', '"', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.']
# [Epoch 163 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'see', 'you', 'on', 'your', 'parents', '.', 'dark', '.', '.', 'do', "n't", 'want', 'to', 'work', '.', 'me', '.', 'list', '.', 'list', '.', 'list', '.', 'list', '.', 'list', '.', 'me', '.', '.', '"', 'i', 'have', 'to', 'read', '.', '"', '"', '.', 'few', 'days', '.', '"', '.', '.', '"']
# [Epoch 164 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'see', 'your', ',', 'where', 'you', 'think', 'of', 'your', 'mother', '.', 'read', 'the', 'summer', '.', 'too', 'station', '.', '"', 'i', "'", 'sisters', '.', '"', '.', 'all', 'i', 'have', 'to', 'read', '.', '"', '"', '.', 'i', '?', '.', '"', '.', '"', '.', '"', '!', 'i', '?', '.', '"', '.']
# [Epoch 165 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'show', 'reading', 'something', 'cool', '.', '.', '.', '.', 'they', 'are', 'too', '.', 'umbrella', '.', '.', '.', '.', 'depend', 'on', 'the', '.', '.', '.', '.', '.', '"', '.', 'all', '.', '.', '"', '.', '"', '"', '.', '"', '"', '.', 'i', "'ll", 'cats', '.', '"', '.', '"', '"', '.']
# [Epoch 166 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'wait', 'to', 'see', 'the', 'right', 'to', 'wait', '.', 'your', 'lost', '.', 'days', '.', '.', 'museum', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'they', 'are', "n't", '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'list', '.']
# [Epoch 167 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'like', 'to', 'listen', 'to', 'me', '.', 'smoking', '.', 'where', 'did', 'you', 'get', 'off', '.', 'list', '.', 'list', '.', '"', '"', 'i', 'turn', 'to', 'tv', '.', '.', '"', '"', 'i', 'think', '.', '.', '.', '"', '"', '!', 'please', '.', '.', '.', '"', '.', 'few', 'all', '.', '"', '"', 'no', '.']
# [Epoch 168 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['miss', 'the', 'you', 'are', "n't", 'like', 'to', 'go', 'out', 'in', 'the', 'same', 'snare', '.', 'few', 'away', '.', '"', 'get', 'rid', 'of', 'my', 'coffee', '.', '"', '"', '.', '"', '"', 'no', '.', '.', '"', '.', 'few', 'up', '.', '"', '"', '.', 'few', 'days', '.', '"', '.', '.', '"', '.', 'barber', "'s"]
# [Epoch 169 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['matter', 'how', 'old', 'you', 'want', 'to', 'watch', 'any', 'book', '?', '"', '"', 'i', 'try', '.', '"', 'your', 'your', '.', '.', '.', '"', '"', 'i', 'get', 'your', 'umbrella', '.', '.', '"', '.', 'bit', '.', '"', '.', 'comes', '.', '"', '.', 'all', 'the', 'flat', '.', '"', '.', '.', '.', '"', '.', '"']
# [Epoch 170 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'stay', 'behind', 'your', 'left', 'your', 'your', 'children', '.', 'on', 'the', 'letter', '.', '.', '.', '.', '.', '.', 'used', 'to', 'get', '.', '.', '.', 'summer', '.', 'summer', '.', 'monday', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 171 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['is', 'you', 'like', 'to', 'smoke', ',', 'and', 'are', "n't", 'sit', 'down', '.', 'teeth', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 172 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['does', "n't", 'want', 'to', 'go', 'to', 'you', 'wherever', 'you', 'want', 'the', 'job', 'from', 'your', 'children', '.', 'smoking', '.', '.', '.', '"', 'on', 'my', '.', '"', '.', 'away', '.', '"', '.', '.', '"', '"', 'i', 'hole', '.', '.', '.', '"', '.', '"', '.', '.', '"', '.', '.', '"', '"', '.', '.']
# [Epoch 173 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['to', 'pick', 'you', 'like', 'to', 'wait', 'for', 'your', 'children', ',', 'you', 'you', 'in', 'your', 'family', '.', '.', 'it', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 174 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'want', 'to', 'brush', 'your', 'family', ',', 'and', 'you', 'to', 'take', 'your', 'dictionary', '.', 'summer', 'work', 'in', 'your', 'father', '.', 'where', 'time', '.', 'relax', '.', '"', '"', 'i', "'", 'get', '.', '.', '"', '.', '"', '"', 'i', 'train', '.', '.', 'thank', 'you', '?', '?', '?', '?', '?', "'", '?', '?']
# [Epoch 175 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['object', 'to', 'do', 'is', ',', 'but', 'your', 'dog', 'is', 'to', 'take', 'pictures', '.', '.', '.', '.', '.', 'they', "'ll", 'miss', 'the', '.', 'movie', '.', '"', '.', '"', '"', '.', 'article', '.', '"', '"', '.', 'visit', '.', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.']
# [Epoch 176 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['is', 'you', 'like', 'to', 'see', 'the', 'and', 'your', 'family', 'walk', 'to', 'visit', 'you', '.', '.', 'your', 'house', '.', '.', 'your', 'umbrella', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'away', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 177 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', 'you', 'want', 'to', 'visit', 'children', 'to', 'show', 'in', 'your', '.', '.', 'movie', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 178 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['is', 'you', 'like', 'to', 'see', 'over', 'these', 'your', 'father', '.', '.', 'dark', '.', '.', '.', '.', '.', 'does', "n't", 'break', '?', '"', '.', 'slip', '.', '"', '.', 'relax', '.', '"', '.', 'all', 'i', 'get', '.', '.', '"', '.', 'year', '.', '.', '"', 'on', '.', '.', '.', '"', '.', 'express', '?']
# [Epoch 179 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'you', 'want', 'to', 'see', 'the', ',', 'you', 'you', 'in', 'your', 'family', '.', 'want', '.', 'to', 'visit', 'you', '.', 'less', 'you', 'wanted', '.', 'visit', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'relax', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 180 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['an', 'picture', ',', 'you', 'want', 'to', 'see', 'your', 'your', 'mother', 'must', '.', 'your', 'family', '.', '.', '.', 'visit', 'you', '.', '.', '.', '.', 'flows', '.', '.', '.', 'flows', '.', '.', '.', 'visit', 'reading', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'relax', '.', '.', '.', '.', '.']
# [Epoch 181 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['is', 'no', 'student', 'on', 'your', 'to', 'visit', 'my', 'house', '.', 'you', '.', 'in', 'your', 'back', '.', '.', 'visit', 'you', '.', '.', 'visit', 'me', '.', 'movie', '.', 'summer', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 182 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['you', 'you', 'want', 'to', 'see', 'me', '.', 'where', 'have', 'you', 'on', 'the', 'museum', '?', '"', '"', 'i', 'have', 'to', 'watch', 'tv', '.', '.', '.', 'visit', 'this', '?', '.', '"', '.', '.', '.', '"', '"', 'i', 'have', 'to', 'watch', 'some', '.', '.', '"', '"', 'take', 'on', '.', '.', '.', 'your', 'should']
# [Epoch 183 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'see', 'the', 'you', 'you', '?', 'your', 'your', 'father', 'off', '.', 'because', 'you', 'are', 'still', '.', '.', 'your', 'house', '?', 'your', 'house', '?', '?', '?', '?', 'your', 'night', '?', '?', '?', 'your', '?', '?', '?', 'your', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 184 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', 'you', 'want', 'to', 'show', 'the', 'to', 'the', 'hotel', ',', 'and', 'you', 'are', "n't", '.', '.', 'your', 'watch', '.', '.', '.', '.', '.', 'visit', '.', '.', '.', '.', '.', '.', '.', '.', 'up', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 185 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', 'you', 'want', 'to', 'watch', 'tv', ',', 'you', 'have', "n't", 'wait', '.', 'your', 'parents', '.', '.', '.', 'look', '.', '.', '.', '.', '.', '.', '.', '.', 'your', 'should', 'visit', 'the', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 186 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', 'you', 'want', 'to', 'watch', 'on', 'tea', 'and', 'i', 'have', 'to', 'watch', '.', 'next', '.', '?', '.', '.', '.', '.', '.', 'go', '.', '.', '.', 'movie', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 187 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'you', 'want', 'to', 'see', 'the', 'show', 'up', 'smoking', '.', 'you', 'do', "n't", 'see', '.', '.', '.', 'give', 'you', 'a', 'nap', '.', '.', '"', '"', 'i', 'think', '.', '.', '.', '"', '"', 'i', 'think', '.', '"', '"', 'i', 'think', '.', 'these', '.', '.', '.', '"', '"', 'i', 'have', 'to']
# [Epoch 188 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["n't", 'you', 'want', 'to', 'see', 'the', 'and', 'your', 'family', 'time', 'like', 'you', 'to', 'visit', 'the', '.', '.', '.', '.', '.', 'go', "n't", 'like', 'to', 'go', 'out', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# [Epoch 189 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["n't", 'enjoy', 'to', 'watch', 'tv', '.', 'you', 'want', 'to', 'see', 'where', 'you', 'go', '.', '.', 'you', 'are', "n't", 'working', '.', '.', 'list', '.', 'color', '.', 'does', "n't", 'remember', '.', '"', '"', 'i', 'do', "n't", 'remember', '.', '.', '.', '.', '"', '.', '.', '"', '.', '.', '"', '.', '.', '"', 'he']
# [Epoch 190 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['would', 'you', 'like', 'to', 'go', 'and', 'some', 'over', 'to', 'the', 'plan', '?', '"', '"', 'i', 'do', 'it', '.', '.', '"', 'your', 'work', '.', '"', '.', 'i', 'have', "n't", 'going', 'to', 'watch', 'my', 'exams', '.', '.', '.', '"', '"', '.', 'i', 'have', 'no', '.', '.', '"', '.', 'all', 'the', 'need', '?']
# [Epoch 191 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ["n't", 'like', 'to', 'watch', 'tv', ',', 'you', 'do', "n't", 'want', 'to', 'go', '.', '.', 'time', '.', '.', 'gives', 'you', '.', '"', '"', 'i', 'take', 'off', '.', '"', '"', 'i', 'always', '.', '.', '"', '.', '"', '"', 'business', '.', '"', '.', '.', '.', '"', '"', 'i', 'have', 'to', 'work', '.', '"']
# [Epoch 192 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['cold', ',', 'i', 'feel', 'like', 'to', 'see', 'you', '?', "n't", 'you', '?', 'on', 'the', 'train', 'or', 'not', '.', 'to', 'go', '.', '.', '"', '"', 'business', '.', '"', '"', 'i', 'have', 'to', 'bed', '.', '"', '.', 'i', 'am', 'on', 'my', 'days', '.', '"', 'no', '.', '"', '.', 'i', 'have', "n't", '.']
# [Epoch 193 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', "n't", 'want', 'to', 'show', 'up', 'on', 'your', 'parents', '.', 'visit', 'me', 'to', 'visit', 'them', '.', '.', 'because', 'you', "'re", 'not', '.', '.', '.', '.', '.', '.', 'does', "n't", 'want', 'to', 'visit', 'me', '.', '"', '"', 'i', 'take', '.', '"', '"', 'the', 'you', '.', '.', '"', '.', '.', '.', '"']
# [Epoch 194 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['do', 'your', 'approval', ',', 'but', 'i', 'want', 'to', 'visit', 'tv', '.', 'why', 'do', "n't", 'remember', '.', 'visit', 'you', '?', '.', '?', 'sleep', '.', 'ever', '.', '.', '"', '.', 'they', 'are', "n't", '.', '.', '"', '.', '.', '"', 'i', 'have', 'to', 'watch', '.', '.', '"', '.', '.', '?', '"', '.', 'exams']
# [Epoch 195 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['matter', 'of', 'you', 'wherever', 'you', 'want', 'to', 'see', 'me', 'the', 'train', '.', "n't", 'you', 'like', '.', 'train', '.', 'why', 'i', 'do', "n't", 'remember', '.', '.', '.', 'give', 'up', 'to', 'pay', '.', 'drinking', '.', '.', '"', 'complaining', '.', '"', '.', 'i', 'have', 'no', '.', '.', '"', '.', 'becomes', '.', '.', '.']
# [Epoch 196 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['with', 'your', 'approval', ',', 'why', 'i', 'want', 'to', 'order', 'to', 'visit', 'you', 'some', '.', '.', 'the', 'color', '.', '?', '?', '?', '?', 'visit', '.', 'visit', '.', 'visit', 'you', '?', '.', '"', 'i', 'have', '.', 'break', '.', 'thank', 'you', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
# [Epoch 197 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['reading', 'the', 'book', 'to', 'you', 'you', "'re", 'not', 'in', 'your', 'parents', '.', 'dark', '.', 'dark', '.', 'not', 'to', 'smoke', '.', 'to', 'bed', 'to', 'your', 'back', '.', '"', '"', 'your', 'you', '.', '.', '"', '.', '.', '"', '"', 'i', 'have', '.', '"', '.', '.', '.', '"', '.', 'color', '.', 'couch', '.']
# [Epoch 198 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['wanted', 'to', 'see', 'the', 'you', 'when', 'you', 'do', "n't", 'look', 'to', 'your', 'children', '?', 'your', 'family', '?', '.', 'give', 'them', 'on', 'the', 'office', '?', '.', 'too', '?', '.', '?', '?', '?', '"', '"', 'i', 'think', '.', '-', 'handed', '.', '"', '"', 'relax', '.', '"', '.', '.', '"', '.', 'you', "'ve"]
# [Epoch 199 / 1000]
# => Saving checkpoint
# Translated example sentence:
#  ['wanted', 'to', 'see', 'you', 'when', 'the', 'way', 'to', 'sit', 'down', 'to', 'the', 'train', '.', '.', 'shoes', '.', 'your', 'uncle', "'s", "n't", '.', '.', 'visit', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
